# %%
happiness_report = pd.read_csv(r"C:\data science\numpy p2\happiness_report.csv")
happiness_report
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %% [markdown]
# # Scatter plot to show the relationship between GDP per capita and happiness score.

# %%
sns.scatterplot(x='GDP per capita', y='Score', data=df, s=100, color='green')

plt.xlabel('GDP per capita')
plt.ylabel('Score')
plt.title('Scatter Plot: GDP per Capita vs Score')

plt.show()

# %% [markdown]
# # 	Heat map to show the correlations between different variables

# %%
correlation_matrix = happiness_report.drop(['Overall rank'], axis=1).corr()
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap: Happiness Chart Variables')
plt.xlabel('Happiness Chart Variables')
plt.ylabel('Happiness Chart Variables')
plt.legend()
plt.show()
# Out:
# C:\Users\karth\AppData\Local\Temp\ipykernel_18348\2610226296.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = happiness_report.drop(['Overall rank'], axis=1).corr()
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Bar plot to show the Happiness score for the top 10 countries.

# %%
# Sort the DataFrame by "Score" in descending order to get the top 10 countries
top_10_countries = happiness_report.sort_values(by='Score', ascending=False).head(10)

# Create the bar plot
plt.figure(figsize=(10, 8))
plt.bar(top_10_countries['Country or region'], top_10_countries['Score'], color='skyblue')

# Add labels and title
plt.xlabel('Country or region')
plt.ylabel('Happiness Score')
plt.title('Happiness Score for Top 10 Countries')




# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Pair Plot to show the relationship between each variable in the dataset.

# %%
sns.pairplot(happiness_report)
plt.show()
